# %%
from model.create_tfrecords import create_tfrecords
from model.train import train_wct
from transfering import transfer_picture
# %matplotlib inline
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# creditsate_tfrecords()

# %%
target_layer = 'relu5'
pretrained_path = r'model_data/vgg19.npy'
max_iterator = 100
checkpoint_path = r'model/model_data'
tfrecord_path = r'model/model_data/tfrecords'
batch_size = 64

# %%
# train_wct(target_layer, pretrained_path, max_iterator, checkpoint_path,
#           tfrecord_path, batch_size)

# %% [markdown]
# In this project we use a pre-trained model since our Surface can not handle such massive task.

# %%
# transfer pictures
pretrained_vgg_path = 'model/model_data/vgg19.npy'
content_path = 'data/content/004.jpg'
style_path = 'data/style/s5.jpg'
output_path = 'data/output/004_s5_trensferred5.jpg'
alpha = 0.5

# %%
transfer_picture(pretrained_vgg_path, content_path, style_path, output_path,
                 alpha,scale = False)
# Out:
# vgg path is:  model/model_data/vgg19.npy
# npy file loaded
# WARNING:tensorflow:From C:\Users\16275\Desktop\Deep Learning\Project\wctTransfer\model\wct_layer.py:34: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Restoring parameters from model/model_data/decoder_1.ckpt
# INFO:tensorflow:Restoring parameters from model/model_data/decoder_2.ckpt
# INFO:tensorflow:Restoring parameters from model/model_data/decoder_3.ckpt
# INFO:tensorflow:Restoring parameters from model/model_data/decoder_4.ckpt
# C:\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Transfer done! Cost 23.313416719436646 secs with Surface Pro 4.
